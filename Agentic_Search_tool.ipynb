# %%
# libraries
from dotenv import load_dotenv
import os
from tavily import TavilyClient

# load environment variables from .env file
_ = load_dotenv()

# connect
client = TavilyClient(api_key=os.environ.get("TAVILY_API_KEY"))

# %%
# run search
result = client.search("What is in Nvidia's new Blackwell GPU?",
                       include_answer=True)

# print the answer
result["answer"]
# Out:
# 'The new Blackwell GPU uses TSMC 4NP node, GDDR7 memory, and features advanced Tensor Cores and NVLink interconnect.'

# %% [markdown]
# ## Regular search

# %%
# choose location (try to change to your own city!)

city = "San Francisco"

query = f"""
    what is the current weather in {city}?
    Should I travel there today?
    "weather.com"
"""

# %%
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS
import re

ddg = DDGS()

def search(query, max_results=6):
    try:
        results = ddg.text(query, max_results=max_results)
        return [i["href"] for i in results]
    except Exception as e:
        print(f"returning previous results due to exception reaching ddg.")
        results = [ # cover case where DDG rate limits due to high deeplearning.ai volume
            "https://weather.com/weather/today/l/USCA0987:1:US",
            "https://weather.com/weather/hourbyhour/l/54f9d8baac32496f6b5497b4bf7a277c3e2e6cc5625de69680e6169e7e38e9a8",
        ]
        return results  


for i in search(query):
    print(i)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6720\2852339428.py:6: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddg = DDGS()
# https://zhidao.baidu.com/question/10035040.html
# https://www.current-news.co.uk/nztc-awards-500000-to-clean-tech-startups/
# https://www.current-news.co.uk/milence-expands-ev-truck-charging-in-germany-france/
# https://www.current-news.co.uk/energy-systems-catapult-launches-smart-data-service-to-speed-net-zero-journey/
# https://www.current-news.co.uk/cornwall-insight-levy-exemptions-could-slash-bills-by-25-for-small-manufacturers/
# https://www.current-news.co.uk/fastned-opens-renewable-energy-powered-north-east-england-ev-charging-hub/

# %%
def scrape_weather_info(url):
    """Scrape content from the given URL"""
    if not url:
        return "Weather information could not be found."
    
    # fetch data
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the webpage."

    # parse result
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
# use DuckDuckGo to find websites and take the first result
url = search(query)[0]

# scrape first wesbsite
soup = scrape_weather_info(url)

print(f"Website: {url}\n\n")
print(str(soup.body)[:50000]) # limit long outputs
# Out:
# Website: https://zhidao.baidu.com/question/10035040.html
#
#
# <body class="layout-center has-menu">
# <div class="userbar userbar-renew fixed qb-search" data="" id="userbar" left-width="880" width="" win-min-width="1280">
# <ul class="aside-list">
# <li>
# <a class="toindex" href="http://www.baidu.com/">ç¾åº¦é¦é¡µ</a>
# </li>
# <li class="shop-entrance">
# <a href="/shop" log="type:2026,pos:top-right,target:shop-entrance" title="ç¥éåå">åå<i class="i-house" style="display: none;"></i></a>
# <span class="lucky-try" style="display: none"></span>
# </li>
# <li><a alog-alias="usrbar-reg" href="https://passport.baidu.com/v2/?reg&amp;tpl=ik&amp;color=green&amp;u=" id="userbar-reg" rel="nofollow" target="_blank">æ³¨å</a></li>
# <li><a alog-alias="usrbar-login" href="javascript:;" id="userbar-login" log="type:2026,pname:account,mod:login,action:show,pos:pop" rel="nofollow">ç»å½</a></li>
# </ul>
# </div>
# <div class="head-wrap">
# <header class="container" id="header">
# <div class="search-box-new line search-box-new-all qb-search-box" id="search-box">
# <ul class="channel grid">
# <li>
# <a class="channel-item-ps" data-type="ps" href="//www.baidu.com/s?ie=utf-8&amp;wd=&amp;cl=3" log="sc_pos:c_ps" rel="nofollow">ç½é¡µ</a>
# </li>
# <li>
# <a class="channel-item-news" data-type="news" href="//www.baidu.com/s?rtt=1&amp;bsst=1&amp;cl=2&amp;tn=news&amp;ie=utf-8&amp;word=&amp;fr=zhidao&amp;dyTabStr=" log="sc_pos:c_news" rel="nofollow">èµè®¯</a>
# </li>
# <li>
# <a class="channel-item-video" data-type="video" href="//www.baidu.com/sf/vsearch?pd=video&amp;tn=vsearch&amp;ie=utf-8&amp;wd=&amp;rsv_spt=16&amp;dyTabStr=" log="sc_pos:c_video" rel="nofollow">è§é¢</a>
# </li>
# <li>
# <a class="channel-item-pic" data-type="pic" href="//image.baidu.com/search/index?tn=baiduimage&amp;ct=201326592&amp;lm=-1&amp;cl=2&amp;word=&amp;t=3&amp;dyTabStr=" log="sc_pos:c_pic" rel="nofollow">å¾ç</a>
# </li>
# <li><strong class="channel-item-zhidao">ç¥é</strong></li>
# <li>
# <a class="channel-item-wenku" data-type="wenku" href="//wenku.baidu.com/search?lm=0&amp;od=0&amp;word=&amp;dyTabStr=" log="sc_pos:c_wenku" rel="nofollow">æåº</a>
# </li>
# <li>
# <a class="channel-item-tieba" data-type="tieba" href="//tieba.baidu.com/f?kw=&amp;t=4&amp;dyTabStr=" log="sc_pos:c_tieba" rel="nofollow">è´´å§</a>
# </li>
# <li>
# <a class="channel-item-b2b" data-type="b2b" href="//b2b.baidu.com/s?q=&amp;fr=www" log="sc_pos:c_b2b" rel="nofollow">éè´­</a>
# </li>
# <li>
# <a class="channel-item-map" data-type="map" href="//map.baidu.com/?newmap=1&amp;ie=utf-8&amp;from=pstab&amp;s=s&amp;wd=&amp;fr=map007" log="sc_pos:c_map" rel="nofollow">å°å¾</a>
# </li>
# <li>
# <a class="channel-item-more" data-type="more" href="//www.baidu.com/more/" log="sc_pos:c_more" rel="nofollow">æ´å¤</a>
# </li>
# </ul>
# <div class="search-block clearfix">
# <div class="search-cont clearfix">
# <a class="logo" href="/" title="ç¾åº¦ç¥é"></a>
# <form action="/search" class="search-form" id="search-form-new" method="get" name="search-form">
# <input autocomplete="off" class="hdi" id="kw" maxlength="256" name="word" placeholder="" size="46" tabindex="1" value=""/>
# <button alog-action="g-search-anwser" class="btn-global" hidefocus="true" id="search-btn" tabindex="2" type="submit">æç´¢ç­æ¡</button>
# <a alog-action="g-i-ask" class="i-ask-link" href="#" id="ask-btn-new">æè¦æé®</a>
# </form>
# </div>
# </div>
# </div>
# <script>
#                         // æç´¢æ¡å¯ç¨æ¶é´æç¹
#                         window.iPerformance && window.iPerformance.mark('c_sbox', +new Date);
#                     </script>
# <div class="wgt-header-title">
# <div class="wgt-header-title-content">
# <h1 class="wgt-header-title-text">è¯·é®ä¸ºä»ä¹çµåçè±ææ¯voltage,ç¼©åå´æ¯uï¼èçµæµè±ææ¯current,ç¼©åæ¯I?</h1>
# <span class="iknow-icons wgt-header-title-btn"> ææ¥ç­</span>
# </div>
# </div>
# </header>
# </div>
# <div class="nav-menu-container" id="j-nav-menu-container">
# <div class="nav-show-control">
# <div class="nav-menu-layout">
# <div class="nav-menu line">
# <div class="nav-menu-content container" style="width: 931px;">
# <div class="content-box">
# <div class="menu-item menu-item-index">
# <a class="menu-title" href="/">
# é¦é¡µ</a>
# </div>
# <div class="menu-item-box">
# <div class="menu-item menu-item-user">
# <a class="menu-title" href="javascript:;" style="cursor: default">
# ç¨æ·<img alt="" class="triangle_icon" src="https://iknow-zhidao.bdimg.com/static/common-new/widget/menu/img/triangle.47e7008.svg"/>
# </a>
# <div class="menu-content">
# <ul class="menu-sub-list">
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="cuser" href="https://baijiahao.baidu.com/builder/rc/rights/list" target="_blank">
# è®¤è¯ç¨æ·</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="cteam" href="/metis/team/decision?fr=daohang" target="_blank">
# è®¤è¯å¢é</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="menu-item menu-item-expert">
# <a class="menu-title" href="/home/partnerhome?fr=daohang" target="_blank">
# <span>
# åä¼äºº<img alt="" class="triangle_icon" src="https://iknow-zhidao.bdimg.com/static/common-new/widget/menu/img/triangle.47e7008.svg"/>
# </span>
# </a>
# <div class="menu-content">
# <ul class="menu-sub-list">
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="rank" href="/activity/page/partner-rank#/1?fr=daohang" target="_blank">
# ç­æ¨æ¦å</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="business" href="/home/partnerhome?fr=daohang" target="_blank">
# ä¼ä¸</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="media" href="/home/partnerhome?fr=daohang" target="_blank">
# åªä½</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="government" href="/home/partnerhome?fr=daohang" target="_blank">
# æ¿åº</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="other" href="/home/partnerhome?fr=daohang" target="_blank">
# å¶ä»ç»ç»</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="menu-right-section">
# <ul class="menu-right-list">
# <li class="menu-right-list-item zhidao-shop">
# <a class="menu-right-list-link" href="/shop" target="_blank">
# <span class="item-name">
# åå</span>
# <span class="new-icon"></span>
# </a>
# </li>
# <li class="menu-right-list-item">
# <a class="menu-right-list-link" href="/law/index" target="_blank">
# <span class="item-name">
# æ³å¾</span>
# </a>
# </li>
# <li class="menu-right-list-item zhidao-app">
# <a class="menu-right-list-link" href="/activity/simpleindexact?tplName=nareplace&amp;type=pc" target="_blank">
# <span class="phone-icon"></span>
# <span class="item-name">
# ææºç­é¢</span>
# </a>
# </li>
# <li class="menu-right-list-item user-center">
# <a class="menu-right-list-link" href="/ihome" target="_blank">
# <span class="item-icon">
# </span>
# <span class="item-name">
# æç</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#             // å¯¼èªå¯ç¨æ¶é´
#             window.iPerformance && window.iPerformance.mark('c_menu', +new Date);
#         </script>
# <div class="container" id="body">
# <div class="layout-wrap">
# <div style="display:none">
# <nav alog-group="qb-cate-nav" class="wgt-nav f-12">
# <a href="/">ç¾åº¦ç¥é</a>
# &gt; æ åç±»</nav>
# </div>
# <section class="line qb-section">
# <article class="grid qb-content" id="qb-content">
# <div class="shadow-task">
# <div class="shadow-task-show-box">
# <img class="shadow-task-show-img" loading="lazy" src="https://iknow-base.cdn.bcebos.com/lxb/notice.png">
# <div class="shadow-task-show"></div>
# </img></div>
# </div>
# <div class="wgt-ask accuse-response line" id="wgt-ask">
# <h1 accuse="qTitle">
# <span class="ask-title">è¯·é®ä¸ºä»ä¹çµåçè±ææ¯voltage,ç¼©åå´æ¯uï¼èçµæµè±ææ¯current,ç¼©åæ¯I?</span>
# <span class="ask-wealth"><i class="iknow-qb_home_icons i-new-wealth"></i><em>10</em></span>
# </h1>
# <div accuse="qContent" class="line mt-5 q-content">
# <span class="con conTemp conSamp">ç´æ¥è¿æ ·è¯´å§ï¼ç©çå­¦ä¸­UåIçå¨ç§°æ¯ä»ä¹...</span>
# <span class="con conReal">
# ç´æ¥è¿æ ·è¯´å§ï¼ç©çå­¦ä¸­UåIçå¨ç§°æ¯ä»ä¹
# </span>
# <a class="expend expend_hide" href="javascript:void(0)">å±å¼<i class="i-incline-down ml-5"></i></a>
# </div>
# <div class="q-video">
# </div>
# <div class="line f-aid ask-info ff-arial" id="ask-info">
# <div class="line wgt-replyer-line">
# <span alog-alias="qb-answer-bar" class="iknow-icons exp-answerbtn-yh" id="answer-bar"> ææ¥ç­</span>
# <ins class="share-area cannotanswer"></ins>
# <ins class="accuse-area cannotanswer"></ins>
# <span id="v-times"></span>
# </div>
# <div class="wgt-search-relate f-yahei f-pening" style="display:none;">
# <p class="title">å¯éä¸­1ä¸ªæå¤ä¸ªä¸é¢çå³é®è¯ï¼æç´¢ç¸å³èµæãä¹å¯ç´æ¥ç¹âæç´¢èµæâæç´¢æ´ä¸ªé®é¢ã</p>
# <ul class="word-list line">
# <li class="word grid"><span class="word-check"><i class="iknow-icons word-check-icon"></i></span><span class="word-text">è±æ</span></li>
# <li class="word grid"><span class="word-check"><i class="iknow-icons word-check-icon"></i></span><span class="word-text">current</span></li>
# <li class="word grid"><span class="word-check"><i class="iknow-icons word-check-icon"></i></span><span class="word-text">çµå</span></li>
# <li class="word grid"><span class="word-check"><i class="iknow-icons word-check-icon"></i></span><span class="word-text">voltage</span></li>
# <li class="word grid }word-last"><span class="word-check"><i class="iknow-icons word-check-icon"></i></span><span class="word-text">ç¼©å</span></li>
# <li class="word grid word-search"><em class="iknow-icons"></em>æç´¢èµæ</li>
# </ul>
# </div>
# <div class="line" data-realname="" id="answer-editor"></div>
# <script id="replyer-addtags-tmpl" type="text/html">
# <div class="addtags-box">
#     <div class="addtags-mask"></div>
#     <div class="addtags-content">
#         <i class="iknow-qb_replyer_icons i-ask-close addtags-close"></i>
#         <div class="addtags-head"><div class="addtags-head-img"></div><span>æäº¤æå</span></div>
#         <div class="addtags-subhead">éæ©æé¿çé¢åç»§ç»­ç­é¢ï¼</div>
#         <div class="tags-box">
#             {@each tagList as item}
#             <li class="{@if item.isQuesTag && item.isQuesTag == 1}selected{@/if}">${item.tagName}</li>
#             {@/each}
#         </div>
#         <div class="addtags-bottom">
#             <div class="addtags-sub">ç»§ç»­åç­</div><div class="addtags-notip ml-10">ä¸åæç¤º</div>
#         </div>
#         <div class='download-app-tip'>
#             <span class="phone-icon-green"></span>
#             <span class="tip-text">ææºåç­æ´æ¹ä¾¿ï¼äºå¨æ´æè¶£ï¼</span><a href='/activity/simpleindexact?tplName=nareplace&type=pc' class="tip-text tip-download-now">ä¸è½½APP</a>
#         </div>
#     </div>
# </div>
# </script>
# <script id="replyer-tags-tmpl" type="text/html">
# <div class="tags-box">
#     <div class="tags-mask"></div>
#     <div class="tags-content">
#         <i class="iknow-qb_replyer_icons i-ask-close tags-close"></i>
#         <div class="tags-head">æäº¤æå</div>
#         <div class="tags-subhead">æ¯å¦ç»§ç»­åç­é®é¢ï¼</div>
#         <div class="tags-bottom">
#             <div class="tags-sub">ç»§ç»­åç­</div><div class="tags-notip ml-10">ä¸åæç¤º</div>
#         </div>
#         <div class='download-app-tip'>
#             <span class="phone-icon-green"></span>
#             <span class="tip-text">ææºåç­æ´æ¹ä¾¿ï¼äºå¨æ´æè¶£ï¼</span><a href='/activity/simpleindexact?tplName=nareplace&type=pc' class="tip-text tip-download-now">ä¸è½½APP</a>
#         </div>
#     </div>
# </div>
# </script>
# <script id="answer-for-lottery" type="text/html">
#     <div class="affairs-box answer-for-lottery">
#         <div class="affairs-mask"></div>
#         <div class="affairs-content">
#             <i class="iknow-qb_replyer_icons i-ask-close affairs-close"></i>
#             <a log="pos:government-affairs-act,action:click" href="https://zhidao.baidu.com/shop/lottery?from=datichoujiang" class="affairs-img">
#                 <img src="https://iknow-base.cdn.bcebos.com/answer-for-lottery.png">
#             </a>
#         </div>
#     </div>
# </script>
# <script id="visit-join-model-template" type="text/html">
#     <p class="visit-join-model-title">å å¥å¢éï¼åä¸ç¾¤å¿åéåä¹äººç¸ç»è¯ï¼ä¸èµ·å¸®å©æ´å¤äºº</p>
#     <div class="visit-join-model-content" id="visit-join-model-content">
#         <div class="carousel-misc"><a href="javascript:void(0);" data-action="left" class="visit-join-control visit-join-control-left visit-join-control-left-disable"></a><a href="javascript:void(0);" data-action="right" class="visit-join-control visit-join-control-right"></a></div>
#     </div>
#     <div class="visit-join-model-warn" id="visit-join-warn">è¯·åéæ©ä¸ä¸ªè¦å å¥çå¢é</div>
# </script>
# </div>
# </div>
# <script>
#     // æé®åºåå¯ç¨æ¶é´
#     window.iPerformance && window.iPerformance.mark('c_ask', +new Date);
# </script>
# <div class="question-all-answers-number">
# <span class="question-all-answers-line"></span>
# <span class="question-all-answers-title" style="font-weight: 700;">10ä¸ªåç­</span>
# <div class="question-number-text-chain">
# <a class="text-chain-wrapper" href="https://zhidao.baidu.com/question/1505363921635298019/answer/4383171583?entry=qb_hotRecommend" log="module:question,page:question,action:click,area:question_text_chain" target="_blank">
# <span class="text-chain-title">#ç­è®®#</span>
# <span class="text-chain-content">çæ´»ä¸­æåªäºå®ç¨çå¿çå­¦ç¥è¯ï¼</span>
# </a>
# </div>
# </div>
# <script type="text/javascript">
#             F.context('answers')['3751436049'] = {uid:"227417193",imId:"public.1.57d92131.I6-hNDQ2gW_fJtlEI5_QxQ",id:"3751436049",userName:"ytlzt",userNameEnc:"ytlzt",user:{sex:"1",iconType:"6",gradeIndex:"5",grAnswerNum:"24",carefield: [{cid:"866",cname:"C/C++"},{cid:"761",cname:"åå²è¯é¢"},{cid:"123",cname:"è¶³ç"},{cid:"211",cname:"åäº"},{cid:"203",cname:"å·¥ç¨ææ¯ç§å­¦"}],isAuth:"0",authTitle:"",isUserAdmin:"0",userAdminLevel:"",userAdminTitle:"",userAdminType:"",isFamous:"0",isMaster:"0",goodRate:"23"},isAnonymous:"0",isCurrentUser:"0",mapUrl:"",refer:"",replyAskNum:"",threadId:"15005744197",hasComment:"0",qid:"10035040",raid:"",recommendCanceled:"0"};
#             F.context('answers')['3751436049'].user && F.context('answers')['3751436049'].user.business && (F.context('answers')['3751436049'].user.business.insType = 0);
#                             F.context('answers')['3751436049'].encodeUid = '691c4069236f25705e798e0d';
#                                         F.context('answers')['3751436049'].ext_pack = {"anony_good_value":"39","dynamic_optime":"1702505253","dynamic_score_detail":"{\"qua_score\":2891,\"time_score\":null,\"ide_score\":null,\"pre_score\":1002889}","from_feedback":"1","mode_begintime":"0","mode_qtype":"0","op_uid":"0","partner":[],"reply_entry":"qb_qb_none"};
#                                         F.context('answers')['3751436049'].bit_pack = {"is_recommend":"0","wap_flag":"0","is_pic_contained":"0","media_flag":"0","help_flag":"0","anonymous":"0","is_really_anonymous":"0","level_new":"1","comment_flag":"0","in_mis":"0","auto_recommend":"0","content_rich_flag":"0","prior_flag":"0","hidden_flag":"0","rec_canceled_flag":"0","mis_flag":"0","file_flag":"0","read_flag":"0","is_challenge":"0","ikaudio_flag":"0","mavin_flag":"0","is_delete_lock":"0","authentic_state":"0","is_compulsory_best":"0","dynamic_stick_flag":"0","video_flag":"0","vote_affirmative":"0","vote_negative":"0","is_video":"0","is_baiduyun":"0","is_yike_card":"0","is_baidumap":"0","is_note":"0"};
#                                 </script>
# <div id="wgt-best">
# <div class="wgt-best" id="best-answer-3751436049">
# <div class="wgt-replyer-all" id="wgt-replyer-all-3751436049">
# <a class="reply-user-tohometip" href="https://zhidao.baidu.com/usercenter?uid=691c4069236f25705e798e0d&amp;role=ugc" target="_blank">
# <div class="wgt-replyer-all-avatar" style="background-image: url(https://himg.bdimg.com/sys/portrait/item/wise.1.f7fab797.zANxYGbr1eBxv4Gw04K84Q.jpg?time=3282&amp;tieba_portrait_time=3282)">
# </div>
# </a>
# <span class="wgt-replyer-all-v ikonw-qb-new-icon"></span>
# <a class="reply-user-tohometip" href="https://zhidao.baidu.com/usercenter?uid=691c4069236f25705e798e0d&amp;role=ugc" target="_blank">
# <span class="wgt-replyer-all-uname">
# ytlzt
# </span>
# </a>
# <br/>
# <span class="wgt-replyer-all-box">
# <span class="wgt-replyer-all-time">
# 2021-09-09
# </span>
# <span>Â·</span>
# <span class="wgt-replyer-all-slogan">
# TAè·å¾è¶è¿481ä¸ªèµ</span>
# </span>
# <div class="level-rank-container rank1" data-level="5">
# <div class="level-rank-content">
# <div class="title">
# <span class="rank-title">ç¥éç­ä¸»</span><span class="level-rank"><i class="rank-icon"></i><i class="level level-5"></i></span>
# </div>
# <div class="user-detail">
# <img class="user-detail-avatar-img" src="https://himg.bdimg.com/sys/portrait/item/wise.1.f7fab797.zANxYGbr1eBxv4Gw04K84Q.jpg?time=3282&amp;tieba_portrait_time=3282"/>
# <div class="user-detail-right">
# <div class="user-detail-p user-detail-p-answer">
# <i class="icon"></i>åç­éï¼<span class="number">152</span>
# </div>
# <div class="user-detail-p user-detail-p-adopt">
# <i class="icon"></i>éçº³çï¼<span class="number">0%</span>
# </div>
# <div class="user-detail-p user-detail-p-help">
# <i class="icon"></i>å¸®å©çäººï¼<span class="number">46.4ä¸</span>
# </div>
# </div>
# </div>
# <div class="user-detail-btn-p">
# <a class="btn toanswer" href="/ihome/homepage/recommendquestion" log="page:question,action:click,area:level-rank-dialog-toanswer,userlevel:5" target="_blank"><span class="btn-text">æä¹å»ç­é¢</span></a><a class="btn tohome reply-user-tohometip" data-ban="0" href="https://zhidao.baidu.com/usercenter?uid=691c4069236f25705e798e0d&amp;role=ugc" log="page:question,action:click,area:level-rank-dialog-tohome,userlevel:5" target="_blank">è®¿é®ä¸ªäººé¡µ</a>
# </div>
# </div>
# </div>
# <div class="wgt-replyer-all-follow-box">
# <span class="wgt-replyer-all-follow" data-follow="0" data-gtype="ugc">å³æ³¨</span>
# <img class="follow-animation" data-src="https://wyw-base.cdn.bcebos.com/pc-content/follow.gif"/>
# </div>
# </div>
# <div class="bd answer" id="answer-3751436049">
# <div class="line info f-aid">
# </div>
# <div class="line content">
# <div accuse="aContent" class="best-text mb-10" id="best-content-3751436049">
# <div class="wgt-best-mask">
# <div class="wgt-best-showbtn">
# å±å¼å¨é¨<span class="wgt-best-arrowdown"></span>
# </div>
# </div>
# <div class="rich-content-container rich-text-">
# éå¸¸ç©çéåè¯¥éçåä½ç¬¦å·ä½¿ç¨çå­æ¯æ¯ä¸åçã<br/>ç©çéçåä½ç¬¦å·ä¸è¬ä½¿ç¨åæï¼åç°ï¼è¯¥ç©çéçç§å­¦å®¶çå§æ°ï¼å¤å½äººå§åæ¯åå¨åé¢ãå§å¨åé¢ï¼çé¦å­æ¯ãä¾å¦çµåçåä½ç¬¦å·æ¯Vï¼ä¸ºäºçºªå¿µæå¤§å©ç©çå­¦å®¶ä¼ç¹ï¼Voltaï¼å¨1800å¹´åæä¼æçµå ãçµæµå¼ºåº¦çåä½ç¬¦å·æ¯Aï¼ä¸ºäºçºªå¿µæ³å½ç©çå­¦å®¶å®å¹ï¼Ampereï¼å¨çµç£å­¦é¢åçç ç©¶æå°±ãçµè·éçåä½ç¬¦å·æ¯Cï¼ä¸ºäºçºªå¿µæ³å½ç©çå­¦å®¶åºä»ï¼Coulombï¼åç°åºä»å®å¾ã<br/>ç©çéä¸è¬ä½¿ç¨è±è¯­ï¼æ³è¯­ãæä¸è¯­ï¼è±è¯­æ¥æºäºæ³è¯­åæä¸è¯­ï¼ä½ä¸ºåç§°ï¼é¦å­æ¯ä½ä¸ºç¬¦å·ãå ä¸ºè±è¯­çµåVoltageçé¦å­æ¯ä¸çµåçåä½ç¬¦å·Vç¸åï¼ä¸ºäºéµå¾ªä½¿ç¨ä¸åå­æ¯çä¼ ç»ï¼ä½¿ç¨å¾·è¯­Underschiedï¼å·®å¼ï¼çé¦å­æ¯Uä½ä¸ºçµåçç¬¦å·ãçµæµçå¨ç§°æ¯çµæµå¼ºåº¦ï¼è±è¯­æ¯Current Intensityï¼å ä¸ºç¬¬ä¸ä¸ªåè¯Currentçé¦å­æ¯ä¸çµè·éçåä½ç¬¦å·Cç¸åï¼ä¸ºäºéµå¾ªä½¿ç¨ä¸åå­æ¯çä¼ ç»ï¼ä½¿ç¨ç¬¬äºä¸ªåè¯Intensityçé¦å­æ¯Iä½ä¸ºçµæµï¼å¼ºåº¦ï¼çç¬¦å·ã
# </div>
# </div>
# <div class="quality-content-view-more mb-15">
# </div>
# <div class="newbest-content-meta line ff-arial">
# <div class="wgt-best-operator clearfix f-aid">
# <img class="wgt-best-operator-shadow" src="data:image/jpeg;base64,..."/>
# <div class="wgt-eva" id="wgt-eva-3751436049">
# <span alog-action="qb-zan-btnbestbox" class="evaluate evaluate-32 evaluate-good-93" data-evaluate="93" id="evaluate-3751436049">
# <i class="ikonw-qb-new-icon icon-evaluate"></i>
# <b class="evaluate-num"></b>
# </span>
# <span class="wgt-eva-pipe"></span>
# <span alog-action="qb-evaluate-outer" class="evaluate-bad evaluate-32" data-evaluate="0" id="evaluate-bad-3751436049">
# <i class="ikonw-qb-new-icon icon-evaluate-bad"></i>
# <b class="evaluate-num"></b>
# </span>
# <span class="wgt-eva-hasgood"><i class="ikonw-qb-new-icon icon-evaluated"></i><b class="evaluate-text">å·²èµè¿</b></span>
# <span class="wgt-eva-hasbad"><i class="ikonw-qb-new-icon icon-evaluated-bad"></i><b class="evaluate-text">å·²è¸©è¿</b>&lt;</span>
# <div class="eva_tooltip">
# <div class="eva_tooltip_arrow">
# <div class="eva_tooltip_arrow_inner"></div>
# </div>
# <div class="eva_tooltip_context">
# ä½ å¯¹è¿ä¸ªåç­çè¯ä»·æ¯ï¼</div>
# </div>
# </div>
# <span alog-action="qb-comment-btnbestbox" class="comment" id="comment-3751436049"><i class="ikonw-qb-new-icon qb-comment-icon"></i>è¯è®º</span>
# <ins class="share-area"></ins>
# <ins alog-alias="qb-accuse-link-best" class="accuse-area" data-rid="3751436049"></ins>
# <span class="wgt-best-hidebtn">æ¶èµ·<i class="wgt-best-arrowup"></i></span>
# </div>
# </div>
# </div>
# </div>
# </div><img class="bottom-dashed-line" src="data:image/png;base64,..." style="margin-top: -10px;"/>
# </div>
# <div class="knowledge-answer fc-c9c404d3d6541977" data-bd_bxst="EiaKIk-RdVnDknMeK00G0cNFY0n0000000000DgZlte21Jo2__rYVXxw8UgDYlQrknoZIhq_IA7Mui1QqIaYzQH2kLyWoQU3VXxKqqrB1_H2kvPdTMF-UMf_zOgfVnoZiHt0000000000006nj0snj0snj0snj0snj0snj0snj0snj0snj0snj0snjaVmzDts7e_zfc000a5hOtmZf000PM8W_mN0f00Ff00000iuy-144id4mzy4pvhluBe4CJg000005OOOOOOOOOOtNpae6" data-bd_vid="nHfdn16LPH03njf4n1bzPH0sn1-xnHcLPNtsg1KxPj7xnHcYrHT1PjRvnWTk" data-ecimtimesign="119" data-expid="1" data-href="https://sp0.baidu.com/9q9JcDHa2gU2pMbgoY3K/km.php?t=AgxFp00000KLANHyYsHDzisK00000rsj9RMf03j6as000000vHTw0PM8W_mN0f00wkQucs000000000000000AXs4fCK0ZE3.uHdCIZwsT1CEQvF1QhF9pywdQhPEUiqsIyF_pynsnzqsmz4Mpym0THLZlte21Jo2__rYVXxw8UgDYlQrknoZIhq_IA7Mui1QqIaYzQH2kLyWoQU3VXxKqqrB1_H2kvPdTMF-UMf_zOgfVnoZiHt0mv_qnj0snj0snj0snj0snj0snj0snj0snj0snj0snj0snj00mHd85HczrjTaUgfqPj0sn6FLUHYs0MFM5HnLg10aIZfqnfFsmLwz5H08njDsrHRk0hu15H0auMfqn0FhuWYs0hFb5HDYn0Fkpyfqn0c0mLFW5HD1nHfk00" data-log="fr:question,pos:qb-answer-uname,si:0,st:2" data-midexpid="" data-pz-sign="119" data-qid="468706576119343605" data-qsign="" data-sign="1758033689342" data-url="http://www.baidu.com/baidu.php?url=a00000jXgoNXZmGYup-ObDrke1iAwOSQg63yLj5UVYuogK9LrHDe0n4Upk7qZOc4p6V8Unok9JWhFO0XtEw_a4aFf1S_JoFNCK85qOpwFOL01pWANPjKopwqOi3OM_atULOYGOJxNDOj0zhNZhcS39sCito0LulV7wCIt1cQQyFSO45ZgP_g_2vjKJ-eZxEy5-3U1EwYlyrLQemcceIfSeqvo0Rs.7R_NR2Ar5Od663mqZw4g_3_acPrQA1JHKePZKILqhFW_lIMWuYeEZGooLtX1WYvU8_yMAkSUq81VOP-93OhOxOdqEyQHW4TjZ4Ev38zUQt81tLeOlZg9WYIjDgeS8l2EGOgSUqS1W7-dqbNIOjSUqSzr2E5YwNvwqXLiSQy4BEGlltHDgeS8l2EGOgSUqS1W7-dqbNIOjSUqSzr2E5YwxEsOoOPSy9vqxCHnkbllpDzmob1nNqXBr6kqle_S5N8OBuO1l_OexdOvTe_xS1SGNSx1Jqxd5Y5OKqOLOSkqDNIOAQqSSetYxWSLWzLXEl7gW_syX5j8O3AWkO3VWY4qhWOutOSKCvxtgH3OJUELO-Z7stXLtdXMu7SLjvxMOUSRIhoGqhhE5SLSUQuOvnAgtdO4EvOqxOmBOxEOgSpl9v1xEOQlPNXhrQqOgs1uxqIYyEkoLxEOQO_xhOxB3OhoOdk1uU5SkPSO7vwxVOl33__guJoSgjSpEtEw7utJO1xEkxoBo93OhOxlxSs_HjSvFL0_nYQAeIYvIB6.U1Yk0ZDqdJo2VVrJ1OJOdN7NwNFu_XJtksKY5fKGUHYknWTd0ZNG5fKspyfqn1T0mv-b5H00mhbqn0KhIjYs0ZKC5H00ULnqn0KBI1Ys0A4Y5H00TLCq0ZFMIA7M5H00UMus5H08nj0snj0snj00ugFM5H00IZF9uARqn0KBuA-b5fKbmvPb5fKYmgFMugfqn7tsg100mgPxpywW5gK1Qy4J0APdujYs0AqW5HD0u1dLTv410AqsnHYs0ZKsPjYs0ZFY5iYk0Z7spyfqn0Kkmv-b5H00mycqn7ts0ZKs5H00Ugws5H00uAwETjYs0ZFJ5H00IZN15HDkrjmznWn4nHbYnWTLPjf3n1040A7W5HD0TA3qn0Ksmgwxuhk9u1Ys0Z7MIvfqn0K-TLfqn0K-IA-b5iYk0A71TAPW5H00IgKGUhPW5H00uhPdIjYs0A7buhk9u1YkPWn3P0KLuMFEUHY0mMfqn0K3TLwd5Hm1rH6krHRL0A-W5H00ThNkIjYkP1R3njn1PW64nWTs0ZPGujdWrynYnjwbnvfvPHfkrHTL0AqY5H00ULFsIjYV0ZFYmy-b5fKopHYs0AdY5H61njR0Uynqn0KVmdqhThqV5H00uA78IyF-gLK_my4GuZnqn0KGTvP_5H00pyw-my-b5HDzPjbLn1fdPWcLnfK8ugIxTAk9UWYknj03rjcknHmd0A4-IdqdUh-Y5HDkrHTLPWfdP1ms0A4-IdqGuAN95HDzPjbLn1fdPWcLnfKsmgP1TAqzIjYs0AF9pywdpyfq0Aq1pyfqn0K9u7q1ULNzmvRqnH6WcsKWThnqnHcvP1n&amp;us=newvui&amp;xst=m1YKT1YkPjR1rjTdnj6sPjb1rHcdnj01rNtknWTdg10KI1YKTHLyJ_JvYlo5SoONTgN-TMhklo1Z0gRqPWn4rjD4PHTKIjYkP1R3njn1PW640ydk5HDan0cV0yPC5yFzmy4b0gFY5H0KnHTsP1RznHmsP0&amp;word=" data-zsyx="nHfdn16LPH03njf4n1bzPH0sn1-xn10s" id="knowledge-answer">
# <div class="knowledge-answer-replyer">
# <img class="knowledge-answer-replyer-avatar" src="https://ecmc.bdimg.com/public03/b4cb859ca634443212c22993b0c87088.png"/>
# <span class="knowledge-answer-replyer-uname">æ¹äºç§æ</span>
# <br/>
# <span class="knowledge-answer-replyer-box">
# <span class="knowledge-answer-replyer-time">2025-08-14</span>
# </span>
# <span class="knowledge-answer-tip">å¹¿å</span>
# </div>
# <div class="knowledge-answer-content">
# <span class="inline-link">
# èç³»çµè¯ï¼19970352726ï¼ä¸æµ·çäºæ°è½æºç§ææéå¬å¸ååå¬å¸èå·æ¹äºç§ææéå¬å¸æ¯å½å®¶é«æ°ææ¯ä¼ä¸ï¼ä¹æ¯èå·âå§èé¢åäººæä¼ä¸â ä¸»è¦æ¹åä¸ºçµæ± å¨çå½å¨æçæ£æµè®¾å¤åæå¡é­ç¯çæé¾åçï¼ä¸»è¦ä¸å¡ä¸ºçµæ± å¨çå½å¨æçæºè½æ£æµåè¯ä»·ï¼æ¯ä¸...
# <span class="green">ç¹å»è¿å¥è¯¦æé¡µ</span>
# </span>
# </div>
# <div class="knowledge-answer-from">
# æ¬åç­ç±<span class="green">æ¹äºç§æ</span>æä¾</div>
# <img class="bottom-dashed-line" src="data:image/png;base64,...

# %%
# extract text
weather_data = []
for tag in soup.find_all(['h1', 'h2', 'h3', 'p']):
    text = tag.get_text(" ", strip=True)
    weather_data.append(text)

# combine all elements into a single string
weather_data = "\n".join(weather_data)

# remove all spaces from the combined text
weather_data = re.sub(r'\s+', ' ', weather_data)
    
print(f"Website: {url}\n\n")
print(weather_data)
# Out:
# Website: https://zhidao.baidu.com/question/10035040.html
#
#
# è¯·é®ä¸ºä»ä¹çµåçè±ææ¯voltage,ç¼©åå´æ¯uï¼èçµæµè±ææ¯current,ç¼©åæ¯I? è¯·é®ä¸ºä»ä¹çµåçè±ææ¯voltage,ç¼©åå´æ¯uï¼èçµæµè±ææ¯current,ç¼©åæ¯I? 10 å¯éä¸­1ä¸ªæå¤ä¸ªä¸é¢çå ³é®è¯ï¼æç´¢ç¸å ³èµæãä¹å¯ç´æ¥ç¹âæç´¢èµæâæç´¢æ´ä¸ªé®é¢ã å ¶ä»ç±»ä¼¼é®é¢ ä¸ºä½ æ¨èï¼ ç¹å«æ¨è ç­ä½ æ¥ç­ ç±»å« æä»¬ä¼éè¿æ¶æ¯ãé®ç®±ç­æ¹å¼å°½å¿«å°ä¸¾æ¥ç»æéç¥æ¨ã è¯´æ 0 /200 æçè´¢å¯å¼ 0 -- æçç°é 0 ä¸è½½ç¾åº¦ç¥éAPP å¨APPç«¯-ä»»å¡ä¸­å¿æç° æç¥éäº -- ç´¯è®¡å®æ ä¸ªä»»å¡ 10ä»»å¡ ç¥ç¥ç¥ç¥â¦ 50ä»»å¡ ç¥ç¥ç¥ç¥â¦ 100ä»»å¡ ç¥ç¥ç¥ç¥â¦ 200ä»»å¡ ç¥ç¥ç¥ç¥â¦ æ¨çè´¦å·ç¶ææ­£å¸¸ æè°¢æ¨å¯¹æä»¬çæ¯æ äº¬ICPè¯030173å·-1 äº¬ç½æã2023ã1034-029å· ©2025Baidu ä½¿ç¨ç¾åº¦åå¿ è¯» | ç¥éåè®® | ä¼ä¸æ¨å¹¿ è¾ å© æ¨¡ å¼

# %%
# run search
result = client.search(query, max_results=1)

# print first result
data = result["results"][0]["content"]

print(data)
# Out:
# {'location': {'name': 'San Francisco', 'region': 'California', 'country': 'United States of America', 'lat': 37.775, 'lon': -122.4183, 'tz_id': 'America/Los_Angeles', 'localtime_epoch': 1758033449, 'localtime': '2025-09-16 07:37'}, 'current': {'last_updated_epoch': 1758033000, 'last_updated': '2025-09-16 07:30', 'temp_c': 15.6, 'temp_f': 60.1, 'is_day': 1, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/day/248.png', 'code': 1135}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 95, 'wind_dir': 'E', 'pressure_mb': 1013.0, 'pressure_in': 29.91, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 96, 'cloud': 0, 'feelslike_c': 15.6, 'feelslike_f': 60.1, 'windchill_c': 13.4, 'windchill_f': 56.2, 'heatindex_c': 13.1, 'heatindex_f': 55.6, 'dewpoint_c': 13.1, 'dewpoint_f': 55.5, 'vis_km': 16.0, 'vis_miles': 9.0, 'uv': 0.0, 'gust_mph': 6.7, 'gust_kph': 10.8}}

# %%
import json
from pygments import highlight, lexers, formatters

# parse JSON
parsed_json = json.loads(data.replace("'", '"'))

# pretty print JSON with syntax highlighting
formatted_json = json.dumps(parsed_json, indent=4)
colorful_json = highlight(formatted_json,
                          lexers.JsonLexer(),
                          formatters.TerminalFormatter())

print(colorful_json)
# Out:
# {
#     "location": {
#         "name": "San Francisco",
#         "region": "California",
#         "country": "United States of America",
#         "lat": 37.775,
#         "lon": -122.4183,
#         "tz_id": "America/Los_Angeles",
#         "localtime_epoch": 1758033449,
#         "localtime": "2025-09-16 07:37"
#     },
#     "current": {
#         "last_updated_epoch": 1758033000,
#         "last_updated": "2025-09-16 07:30",
#         "temp_c": 15.6,
#         "temp_f": 60.1,
#         "is_day": 1,
#         "condition": {
#             "text": "Fog",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/248.png",
#             "code": 1135
#         },
#         "wind_mph": 2.2,
#         "wind_kph": 3.6,
#         "wind_degree": 95,
#         "wind_dir": "E",
#         "pressure_mb": 1013.0,
#         "pressure_in": 29.91,
#         "precip_mm": 0.0,
#         "precip_in": 0.0,
#         "humidity": 96,
#         "cloud": 0,
#         "feelslike_c": 15.6,
#         "feelslike_f": 60.1,
#         "windchill_c": 13.4,
#         "windchill_f": 56.2,
#         "heatindex_c": 13.1,
#         "heatindex_f": 55.6,
#         "dewpoint_c": 13.1,
#         "dewpoint_f": 55.5,
#         "vis_km": 16.0,
#         "vis_miles": 9.0,
#         "uv": 0.0,
#         "gust_mph": 6.7,
#         "gust_kph": 10.8
#     }
# }
